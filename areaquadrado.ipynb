# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoGabini/PA2025/blob/main/areaquadrado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Saindo da maldição

# %%
aula = "hello world"

# %%
aula
# Out:
# 'hello world'

# %% [markdown]
# # Primeiro código

# %%
#Entrada
lado = 4

# %%
#processamento
area = lado * lado

# %%
#saída
print("A área do quadrado é",area)
# Out:
# A área do quadrado é 16
